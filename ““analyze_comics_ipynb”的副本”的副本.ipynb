# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/zihangJiang/community_detection/blob/master/%E2%80%9C%E2%80%9Canalyze_comics_ipynb%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb)

# %% [markdown]
# # Homework - Network Analysis
# In this homework you are to compute some descriptive statistics of a large graph.
#
# The first part of this notebook constructs the graph for your analysis. The latter part consists of your <a href="#scrollTo=eHdAbCpQ-z1J">homework</a>.
#
# The purpose of this homework is to familiarize you with Python syntax and methods. Hence, you are free to search the internet for hints and new ways to solve the problems herein.
#
# *Regarding the graph:*<br>
# *The data used in this homework is mainly obtained from http://www.manga109.org/en/, with a couple of additions.*<br>
# *The similarity between two comics has been computed in a way similar to the earlier lab "Community Detection", but with dissimilarity scores between 0.5 and 1.*
#
#
# ---

# %% [markdown]
# ##Test case name
# *Do not change the name for this homework. Leave it as "manga109".*

# %%
name="manga109"

# %% [markdown]
# ## Imports

# %%
# Install GCP modules

# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools

# Install NetworkX module

# !pip3 install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (2.1)
# Requirement already satisfied: decorator>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from networkx) (4.3.0)

# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt
import PIL.ImageOps    
from PIL import Image
import numpy as np
import itertools
import math
import os
from google.colab import files, auth

# %% [markdown]
# ## Helper functions

# %%
def imshow(img):
    npimg = img.numpy()
    plt.axis("off")
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration, loss):
    plt.plot(iteration, loss)
    plt.show()
    
# Set use_gcp to False to download a file to your local harddisk
def backup(filename, use_gcp=True):
    if name == "trial" and use_gcp: # No backup for the trial
        print("File \"" + filename + "\" not backed up since this is a trial run")
        return
    if use_gcp:
        project_id = 'twitter-for-bigquery'
        auth.authenticate_user()
        os.system("gcloud config set project twitter-for-bigquery")
        os.system("gsutil copy " + filename + " gs://harddisk-1/" + name + "/")
    else:
        files.download(filename)

# Set use_gcp to False to upload a file from your local harddisk
def restore(filename, use_gcp=True):
    if use_gcp:
        project_id = 'twitter-for-bigquery'
        auth.authenticate_user()
        os.system("gcloud config set project twitter-for-bigquery")
        os.system("gsutil copy gs://harddisk-1/" + name + "/" + filename + " .")
    else:
        if os.path.exists(filename):
            os.remove(filename)
        uploaded = files.upload()
    # !ls -l {filename}

# Creates a NetworkX graph object
def make_graph(sim, labels=None):
    G = nx.Graph()
    for i in range(sim.shape[0]):
        for j in range(sim.shape[1]):
            if i != j and sim[i,j] != 0:
                if labels == None:
                    G.add_edge(i, j, weight=sim[i,j])
                else:
                    G.add_edge(labels[i], labels[j], weight=sim[i,j])
    return G

# Save graph for use in Gephi or pals
def export_edge_list(sim, labels=None, filename="edges.csv", delim=",", header=True):
    f = open(filename, 'w')
    if header:
        f.write("Source,Target\n")
    for i in range(sim.shape[0]):
        for j in range(i+1, sim.shape[1]):
            if sim[i,j] != 0:
                if labels == None:
                    f.write(str(i) + delim + str(j) + "\n")
                else:
                    f.write("\"" + labels[i] + "\"" + delim + "\"" + labels[j] + "\"\n")                          
    f.close()

# %% [markdown]
# ##Configuration

# %%
class Config():
    colors = ['aquamarine', 'bisque', 'blanchedalmond', 'blueviolet', 'brown',
              'burlywood', 'cadetblue', 'chartreuse','chocolate', 'coral',
              'cornflowerblue', 'cornsilk', 'crimson', 'darkblue', 'darkcyan',
              'darkgoldenrod', 'darkgray', 'darkgreen', 'darkgrey', 'darkkhaki',
              'darkmagenta', 'darkolivegreen', 'darkorange', 'darkslateblue',
              'darkorchid', 'darkred', 'darksalmon', 'darkseagreen',
              'darkslategray', 'darkslategrey', 'darkturquoise', 'darkviolet',
              'deeppink', 'deepskyblue', 'dimgray', 'dimgrey', 'dodgerblue',
              'firebrick', 'floralwhite', 'forestgreen', 'fuchsia', 'gainsboro',
              'ghostwhite', 'gold', 'goldenrod', 'gray', 'green', 'greenyellow',
              'grey', 'honeydew', 'hotpink', 'indianred', 'indigo', 'ivory']
    labels = None

# %% [markdown]
# ---
#
#
# ## Build graph
# Construct an adjacency matrix from the dissimilarity matrix, then use the adjacency matrix to build a networkx graph

# %%
# Load a saved copy of the dissimilarity matrix

simfilename = "_sim.tsv"
labelfilename = "_labels.csv"

restore(simfilename)

X = np.genfromtxt(simfilename, delimiter='\t', encoding='utf8', dtype=None)
label2idx = dict()
sim = np.ones((len(X), len(X)))
if os.path.exists(labelfilename):
    os.remove(labelfilename)
f = open(labelfilename, 'w')
for t in X:
    t0, t1, t2 = t
    if not t0 in label2idx:
        idx = len(label2idx)
        label2idx[t0] = idx
        f.write(str(idx) + "," + t0 + "\n")
    if not t1 in label2idx:
        idx = len(label2idx)
        label2idx[t1] = len(label2idx)
        f.write(str(idx) + "," + t1 + "\n")
    idx0 = label2idx[t0]
    idx1 = label2idx[t1]
    sim[idx0][idx1] = t2
    sim[idx1][idx0] = t2
f.close()
    
print("Restored {}x{} matrix".format(sim.shape[0], sim.shape[1]))
# Out:
# -rw-r--r-- 1 root root 269002 Jul 16 05:17 _sim.tsv
# Restored 7260x7260 matrix

# %%
# Restore labels from saved "_labels.csv" file

restore("_labels.csv")

Config.labels = []
with open('_labels.csv') as f:
    for line in f:
        _, label = line.rstrip().split(",")
        Config.labels.append(label)

print("Loaded labels (" + str(len(Config.labels)) + " classes): ", end='')
print(Config.labels)
# Out:
# -rw-r--r-- 1 root root 2196 Jul 16 05:17 _labels.csv
# Loaded labels (121 classes): ['AisazuNihaIrarenai', 'AkkeraKanjinchou', 'Akuhamu', 'AosugiruHaru', 'AppareKappore', 'Arisa', 'BakuretsuKungFuGirl', 'Belmondo', 'BEMADER_P', 'BlackJack', 'BokuHaSitatakaKun', 'Buddha', 'BurariTessenTorimonocho', 'ByebyeC-BOY', 'Count3DeKimeteAgeru', 'DareMoNeteWaNaranu', 'DollGun', 'Donburakokko', 'DualJustice', 'EienNoWith', 'EvaLady', 'EverydayOsakanaChan', 'GakuenNoise', 'GarakutayaManta', 'GinNoChimera', 'GOOD_KISS_Ver2', 'Hamlet', 'HanzaiKousyouninMinegishiEitarou', 'HaruichibanNoFukukoro', 'HarukaRefrain', 'HealingPlanet', 'HeiseiJimen', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'HinagikuKenzan', 'HisokaReturns', 'HyougeMono', 'JangiriPonpon', 'JijiBabaFight', 'Jin', 'Joouari', 'Jyovolley', 'KarappoHighschool', 'KatteNiKaizoEd', 'KatteNiKaizoSt', 'KimiHaBokuNoTaiyouDa', 'Kiseiju', 'KonnaBlackJackWaIyada', 'KoukouNoHitotachi', 'KuroidoGanka', 'KyokugenCyclone', 'LancelotFullThrottle', 'LoveHina_vol01', 'LoveHina_vol14', 'MAD_STONE', 'MadouTaiga', 'MagicianLoad', 'MagicStarGakuin', 'MariaSamaNihaNaisyo', 'MayaNoAkaiKutsu', 'MemorySeijin', 'MeteoSanStrikeDesu', 'MiraiSan', 'MisutenaideDaisy', 'MitsumeGaTooru', 'MoeruOnisan_vol01', 'MoeruOnisan_vol19', 'MomoyamaHaikagura', 'MukoukizuNoChonbo', 'MunakataKyoujiuDenkikou', 'MutekiBoukenSyakuma', 'Nekodama', 'NichijouSoup', 'Ningyoushi', 'OhWareraRettouSeitokai', 'OL_Lunch', 'OlympusNoBoron', 'ParaisoRoad', 'PikaruGenkiDesu', 'PLANET7', 'PlatinumJungle', 'PrayerHaNemurenai', 'PrismHeart', 'PsychoStaff', 'Raphael', 'ReveryEarth', 'RinToSiteSippuNoNaka', 'RisingGirl', 'Saisoku', 'SaladDays_vol01', 'SaladDays_vol18', 'SamayoeruSyonenNiJunaiWo', 'SayonaraZetsubouSenseiEd', 'SayonaraZetsubouSenseiSt', 'SeisinkiVulnus', 'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26', 'SonokiDeABC', 'SyabondamaKieta', 'TaiyouNiSmash', 'TapkunNoTanteisitsu', 'TasogareTsushin', 'TennenSenshiG', 'TensiNoHaneToAkumaNoShippo', "That'sIzumiko", 'TotteokiNoABC', 'ToutaMairimasu', 'TouyouKidan', 'TsubasaNoKioku', "UchiNoNyan'sDiary", 'UchuKigekiM774', 'UltraEleven', 'UnbalanceTokyo', 'WarewareHaOniDearu', 'YamatoNoHane', 'YasasiiAkuma', 'YoumaKourin', 'YukiNoFuruMachi', 'YumeiroCooking', 'YumeNoKayoiji', 'ARMS']

# %%
# Analyze distribution of dissimilarity score

simflat = sim.reshape((-1,))
simflat = simflat[simflat != 1] # Too many ones result in a bad histogram so we remove them
_ = plt.hist(simflat, bins=25)

mmax  = np.max(simflat)
mmin  = np.min(simflat)
mmean = np.mean(simflat)
print('avg={0:.2f} min={1:.2f} max={2:.2f}'.format(mmean, mmin, mmax))
# Out:
# avg=0.90 min=0.50 max=0.97

# %%
# Select a suitable threshold and set dissimilarity scores larger than that threshold to zero

threshold = 0.82 # Replace this with your choice of threshold
adjmat = sim.copy()
np.fill_diagonal(adjmat, np.min(sim)) # Set the diagonal elements to a small value so that they won't be zeroed out
adjmat = adjmat.reshape((-1,))
adjmat[adjmat > threshold] = 0
#adjmat[adjmat > 0] = 1
print("{} out of {} values set to zero".format(len(adjmat[adjmat == 0]), len(adjmat)))
adjmat = adjmat.reshape(sim.shape)
# Out:
# 52699162 out of 52707600 values set to zero

# %%
# Construct a networkx graph from the adjacency matrix
# (Singleton nodes are excluded from the graph)

G = make_graph(adjmat, labels=Config.labels)
nx.draw(G, with_labels=True)

# %% [markdown]
# ---
#
#
# ##Community detection using Girvan-Newman

# %%
from networkx.algorithms.community.centrality import girvan_newman

comp = girvan_newman(G)

max_shown = 12
shown_count = 1
possibilities = []
for communities in itertools.islice(comp, max_shown):
    print("Possibility", shown_count, ": ", end='')
    print(communities)
    possibilities.append(communities)
    color_map = ["" for x in range(len(G))]
    color = 0
    for c in communities:
        indices = [i for i, x in enumerate(G.nodes) if x in c]
        for i in indices:
            color_map[i] = Config.colors[color]
        color += 1
    shown_count += 1
    nx.draw(G, node_color=color_map, with_labels=True)
    plt.show()
# Out:
# Possibility 1 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'UchuKigekiM774', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'TouyouKidan', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'HarukaRefrain', 'ToutaMairimasu', 'SeisinkiVulnus', 'EverydayOsakanaChan', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'YamatoNoHane', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'MukoukizuNoChonbo', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'JijiBabaFight', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', "That'sIzumiko", 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'DareMoNeteWaNaranu', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'OlympusNoBoron', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 2 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'UchuKigekiM774', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'TouyouKidan', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'HarukaRefrain', 'ToutaMairimasu', 'SeisinkiVulnus', 'EverydayOsakanaChan', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'YamatoNoHane', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'MukoukizuNoChonbo', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'JijiBabaFight', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', "That'sIzumiko", 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'OlympusNoBoron', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'DareMoNeteWaNaranu'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 3 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'UchuKigekiM774', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'TouyouKidan', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'HarukaRefrain', 'ToutaMairimasu', 'SeisinkiVulnus', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'YamatoNoHane', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'MukoukizuNoChonbo', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'JijiBabaFight', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', "That'sIzumiko", 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'OlympusNoBoron', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'DareMoNeteWaNaranu'}, {'EverydayOsakanaChan'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 4 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'UchuKigekiM774', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'TouyouKidan', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'HarukaRefrain', 'ToutaMairimasu', 'SeisinkiVulnus', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'YamatoNoHane', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'MukoukizuNoChonbo', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', "That'sIzumiko", 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'OlympusNoBoron', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'DareMoNeteWaNaranu'}, {'EverydayOsakanaChan'}, {'JijiBabaFight'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 5 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'TouyouKidan', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'HarukaRefrain', 'ToutaMairimasu', 'SeisinkiVulnus', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'YamatoNoHane', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'MukoukizuNoChonbo', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', "That'sIzumiko", 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'OlympusNoBoron', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'DareMoNeteWaNaranu'}, {'EverydayOsakanaChan'}, {'JijiBabaFight'}, {'UchuKigekiM774'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 6 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'TouyouKidan', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'HarukaRefrain', 'ToutaMairimasu', 'SeisinkiVulnus', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'YamatoNoHane', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'MukoukizuNoChonbo', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', "That'sIzumiko", 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'DareMoNeteWaNaranu'}, {'EverydayOsakanaChan'}, {'JijiBabaFight'}, {'UchuKigekiM774'}, {'OlympusNoBoron'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 7 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'TouyouKidan', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'HarukaRefrain', 'ToutaMairimasu', 'SeisinkiVulnus', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'YamatoNoHane', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', "That'sIzumiko", 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'DareMoNeteWaNaranu'}, {'EverydayOsakanaChan'}, {'JijiBabaFight'}, {'MukoukizuNoChonbo'}, {'UchuKigekiM774'}, {'OlympusNoBoron'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 8 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'TouyouKidan', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'HarukaRefrain', 'ToutaMairimasu', 'SeisinkiVulnus', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', "That'sIzumiko", 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'DareMoNeteWaNaranu'}, {'EverydayOsakanaChan'}, {'JijiBabaFight'}, {'MukoukizuNoChonbo'}, {'UchuKigekiM774'}, {'OlympusNoBoron'}, {'YamatoNoHane'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 9 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'TouyouKidan', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'ToutaMairimasu', 'SeisinkiVulnus', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', "That'sIzumiko", 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'DareMoNeteWaNaranu'}, {'EverydayOsakanaChan'}, {'HarukaRefrain'}, {'JijiBabaFight'}, {'MukoukizuNoChonbo'}, {'UchuKigekiM774'}, {'OlympusNoBoron'}, {'YamatoNoHane'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 10 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'TouyouKidan', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'ToutaMairimasu', 'SeisinkiVulnus', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'DareMoNeteWaNaranu'}, {'EverydayOsakanaChan'}, {'HarukaRefrain'}, {'JijiBabaFight'}, {'MukoukizuNoChonbo'}, {'UchuKigekiM774'}, {"That'sIzumiko"}, {'OlympusNoBoron'}, {'YamatoNoHane'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 11 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'ToutaMairimasu', 'SeisinkiVulnus', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'HealingPlanet', 'GakuenNoise', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'DareMoNeteWaNaranu'}, {'TouyouKidan'}, {'EverydayOsakanaChan'}, {'HarukaRefrain'}, {'JijiBabaFight'}, {'MukoukizuNoChonbo'}, {'UchuKigekiM774'}, {"That'sIzumiko"}, {'OlympusNoBoron'}, {'YamatoNoHane'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})
# Possibility 12 : ({'RisingGirl', 'TsubasaNoKioku', 'YoumaKourin', 'AppareKappore', 'UnbalanceTokyo', 'SaladDays_vol18', 'SyabondamaKieta', 'KonnaBlackJackWaIyada', 'NichijouSoup', 'Ningyoushi', 'MAD_STONE', 'MariaSamaNihaNaisyo', 'HinagikuKenzan', 'AisazuNihaIrarenai', 'BlackJack', 'BakuretsuKungFuGirl', 'BEMADER_P', 'DollGun', 'MagicStarGakuin', 'TennenSenshiG', 'KarappoHighschool', 'Jin', 'BurariTessenTorimonocho', 'TasogareTsushin', 'SamayoeruSyonenNiJunaiWo', 'HisokaReturns', 'TaiyouNiSmash', 'ToutaMairimasu', 'SeisinkiVulnus', 'HeiseiJimen', 'AosugiruHaru', 'LoveHina_vol14', 'LancelotFullThrottle', 'Saisoku', 'Arisa', 'PLANET7', "UchiNoNyan'sDiary", 'Jyovolley', 'YasasiiAkuma', 'TapkunNoTanteisitsu', 'SonokiDeABC', 'EienNoWith', 'YumeNoKayoiji', 'MisutenaideDaisy', 'MomoyamaHaikagura', 'Belmondo', 'JangiriPonpon', 'Nekodama', 'KatteNiKaizoSt', 'OhWareraRettouSeitokai', 'TensiNoHaneToAkumaNoShippo', 'UltraEleven', 'MeteoSanStrikeDesu', 'ByebyeC-BOY', 'TotteokiNoABC', 'MoeruOnisan_vol19', 'ParaisoRoad', 'PrismHeart', 'RinToSiteSippuNoNaka', 'DualJustice', 'KuroidoGanka', 'HighschoolKimengumi_vol01', 'HighschoolKimengumi_vol20', 'EvaLady', 'SaladDays_vol01', 'LoveHina_vol01', 'Count3DeKimeteAgeru', 'MagicianLoad', 'PrayerHaNemurenai', 'Raphael', 'GarakutayaManta', 'Hamlet', 'ReveryEarth', 'MadouTaiga', 'AkkeraKanjinchou', 'Donburakokko', 'PsychoStaff', 'YumeiroCooking', 'PlatinumJungle', 'GOOD_KISS_Ver2', 'PikaruGenkiDesu', 'GinNoChimera', 'KyokugenCyclone', 'Kiseiju', 'MutekiBoukenSyakuma', 'BokuHaSitatakaKun', 'MayaNoAkaiKutsu', 'Buddha', 'MunakataKyoujiuDenkikou', 'MitsumeGaTooru', 'GakuenNoise', 'YukiNoFuruMachi', 'WarewareHaOniDearu', 'HaruichibanNoFukukoro', 'MemorySeijin', 'MoeruOnisan_vol01', 'HanzaiKousyouninMinegishiEitarou'}, {'KoukouNoHitotachi', 'Akuhamu', 'OL_Lunch'}, {'ShimatteIkouze_vol01', 'ShimatteIkouze_vol26'}, {'HealingPlanet'}, {'DareMoNeteWaNaranu'}, {'TouyouKidan'}, {'EverydayOsakanaChan'}, {'HarukaRefrain'}, {'JijiBabaFight'}, {'MukoukizuNoChonbo'}, {'UchuKigekiM774'}, {"That'sIzumiko"}, {'OlympusNoBoron'}, {'YamatoNoHane'}, {'SayonaraZetsubouSenseiSt', 'SayonaraZetsubouSenseiEd'})

# %%
# Generate and download edges for Gephi

export_edge_list(adjmat, labels=Config.labels, filename='gephi-edges.csv')
backup('gephi-edges.csv', False)

# %% [markdown]
# ---
#
#
# ##Homework
# <a id="homework"></a>
# Complete the questions below. The first question should be straightforward.

# %% [markdown]
# ###Q1. Generate the edge file and community file for the pals system.

# %%
# Generate the community file for pals system

which_possibility = 12

communities = possibilities[which_possibility-1]

indices_in_community = []   # For obtaining submatrix of adjmat

f = open("pals-community.dat", 'w')
cur_com = 1
for c in communities:
    indices = [i for i, x in enumerate(Config.labels) if x in c]
    indices_in_community.extend(indices)
    for i in indices:
         f.write("\"" + Config.labels[i] + "\" " + str(cur_com) + "\r\n")
    cur_com += 1
f.close()

backup("pals-community.dat", False)


# Generate the graph file for pals system

# Obtain the submatrix of adjmat with only elements that appear in communities
indices_in_community = sorted(indices_in_community)
adjmat_in_community = adjmat[indices_in_community,:][:,indices_in_community]

# Obtain sublist of labels of only elements that appear in communities
labels = np.array(Config.labels)[indices_in_community].tolist()

export_edge_list(adjmat_in_community, labels=labels, filename='pals-edges.dat', delim=" ", header=False)

backup('pals-edges.dat', False)

# %% [markdown]
# ###Q2. Find the node with the most number of neighbors

# %%
def export_edge_list2(sim, labels=None):
    edge_list = []
    for i in range(sim.shape[0]):
        for j in range(i+1, sim.shape[1]):
            if sim[i,j] != 0:
                if labels == None:
                    edge_list.append(str(i))
                    edge_list.append(str(j))
                else:
                    edge_list.append(labels[i])
                    edge_list.append(labels[j])                        
    return edge_list
edge_count = export_edge_list2(adjmat_in_community, labels=labels)
from collections import Counter
most_c = Counter(edge_count).most_common(1)[0][0]
print(most_c)
# Out:
# Arisa

# %% [markdown]
# ### Q3. List the neighbors of the node (with the most neighbors) found above

# %%
for i,node in enumerate(edge_count):
  if node == most_c:
    if i%2 == 0:
      print(edge_count[i+1])
    else:
      print(edge_count[i-1])
# Out:
# AppareKappore
# BakuretsuKungFuGirl
# Belmondo
# BlackJack
# Count3DeKimeteAgeru
# DualJustice
# EvaLady
# GakuenNoise
# GinNoChimera
# GOOD_KISS_Ver2
# HaruichibanNoFukukoro
# HealingPlanet
# HeiseiJimen
# HinagikuKenzan
# HisokaReturns
# Jyovolley
# KatteNiKaizoSt
# Kiseiju
# KuroidoGanka
# LancelotFullThrottle
# LoveHina_vol14
# MAD_STONE
# MadouTaiga
# MagicStarGakuin
# MemorySeijin
# MeteoSanStrikeDesu
# MisutenaideDaisy
# MitsumeGaTooru
# Nekodama
# NichijouSoup
# ParaisoRoad
# PrayerHaNemurenai
# PsychoStaff
# Raphael
# ReveryEarth
# SaladDays_vol01
# SaladDays_vol18
# SonokiDeABC
# SyabondamaKieta
# TapkunNoTanteisitsu
# TennenSenshiG
# ToutaMairimasu
# UltraEleven
# YumeiroCooking

# %% [markdown]
# ###Q4. Plot a histogram of the degrees of the nodes in the graph

# %%
 _ = plt.hist([j[1] for j in Counter(edge_count).most_common()],bins = 43)

# %% [markdown]
# ###Q5. Produce a list of the nodes sorted from that with the most neighbors to that with the least neighbors

# %%
[j[0] for j in Counter(edge_count).most_common()]
# Out:
# ['Arisa',
#  'DualJustice',
#  'SaladDays_vol18',
#  'Donburakokko',
#  'SaladDays_vol01',
#  'Count3DeKimeteAgeru',
#  'TennenSenshiG',
#  'EvaLady',
#  'ToutaMairimasu',
#  'Jyovolley',
#  'KuroidoGanka',
#  'PsychoStaff',
#  'AppareKappore',
#  'LoveHina_vol01',
#  'UnbalanceTokyo',
#  'HeiseiJimen',
#  'MitsumeGaTooru',
#  'MAD_STONE',
#  'HisokaReturns',
#  'YoumaKourin',
#  'SonokiDeABC',
#  'LancelotFullThrottle',
#  'MadouTaiga',
#  'HaruichibanNoFukukoro',
#  'UltraEleven',
#  'AkkeraKanjinchou',
#  'LoveHina_vol14',
#  'TasogareTsushin',
#  'WarewareHaOniDearu',
#  'MeteoSanStrikeDesu',
#  'ParaisoRoad',
#  'TapkunNoTanteisitsu',
#  'TensiNoHaneToAkumaNoShippo',
#  'YukiNoFuruMachi',
#  'YumeiroCooking',
#  'MisutenaideDaisy',
#  'SyabondamaKieta',
#  'PlatinumJungle',
#  'DollGun',
#  'GakuenNoise',
#  'GinNoChimera',
#  'Belmondo',
#  'BurariTessenTorimonocho',
#  'KarappoHighschool',
#  'Saisoku',
#  'BEMADER_P',
#  'ReveryEarth',
#  'TotteokiNoABC',
#  'OhWareraRettouSeitokai',
#  'MemorySeijin',
#  'Buddha',
#  'NichijouSoup',
#  'PrayerHaNemurenai',
#  'YasasiiAkuma',
#  'BakuretsuKungFuGirl',
#  'BlackJack',
#  'KatteNiKaizoSt',
#  'BokuHaSitatakaKun',
#  'YumeNoKayoiji',
#  'GarakutayaManta',
#  'GOOD_KISS_Ver2',
#  'Kiseiju',
#  'EienNoWith',
#  'KonnaBlackJackWaIyada',
#  'HighschoolKimengumi_vol01',
#  'HighschoolKimengumi_vol20',
#  'RisingGirl',
#  'PrismHeart',
#  'AosugiruHaru',
#  'MayaNoAkaiKutsu',
#  'TaiyouNiSmash',
#  'MoeruOnisan_vol01',
#  'MagicianLoad',
#  'PikaruGenkiDesu',
#  'MunakataKyoujiuDenkikou',
#  'AisazuNihaIrarenai',
#  'MariaSamaNihaNaisyo',
#  'Jin',
#  'HinagikuKenzan',
#  'MagicStarGakuin',
#  'Nekodama',
#  'TsubasaNoKioku',
#  'Hamlet',
#  'JangiriPonpon',
#  'Ningyoushi',
#  'MomoyamaHaikagura',
#  'SeisinkiVulnus',
#  'KyokugenCyclone',
#  'ShimatteIkouze_vol01',
#  'Raphael',
#  'MutekiBoukenSyakuma',
#  'MoeruOnisan_vol19',
#  'ByebyeC-BOY',
#  'Akuhamu',
#  'HanzaiKousyouninMinegishiEitarou',
#  'HealingPlanet',
#  'SamayoeruSyonenNiJunaiWo',
#  'PLANET7',
#  'TouyouKidan',
#  "UchiNoNyan'sDiary",
#  'RinToSiteSippuNoNaka',
#  'KoukouNoHitotachi',
#  'OL_Lunch',
#  'DareMoNeteWaNaranu',
#  'EverydayOsakanaChan',
#  'HarukaRefrain',
#  'JijiBabaFight',
#  'MukoukizuNoChonbo',
#  'UchuKigekiM774',
#  "That'sIzumiko",
#  'OlympusNoBoron',
#  'YamatoNoHane',
#  'SayonaraZetsubouSenseiEd',
#  'SayonaraZetsubouSenseiSt',
#  'ShimatteIkouze_vol26']
